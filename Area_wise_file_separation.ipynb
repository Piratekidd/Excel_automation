# %%
import pandas as pd

# Replace 'file_path.xlsx' with the path to your Excel filex
df = pd.read_excel("F:\Daily Reports\center_size.xlsx")

# Display the first few rows of the DataFrame to verify the import
df.head()
# Out:
#              zone          region     branch                center group_val  \
# 0      Z103|BIHAR  R104|Darbhanga  Darbhanga       imali-ghat_3000       NaN
# 1      Z103|BIHAR  R104|Darbhanga  Darbhanga       imali-ghat_3000       NaN
# 2      Z103|BIHAR  R104|Darbhanga  Darbhanga        beladulla_3001       NaN
# 3  Z102|KARNATAKA  R103|Kalaburgi  Kalaburgi  prashant-nagar _3002       NaN
# 4  Z102|KARNATAKA  R103|Kalaburgi  Kalaburgi  prashant-nagar _3002       NaN
#
#         customer_created_by       customer_updated_by  customer_id  \
# 0  SF00084|Trilok Kumar Sah  SF00084|Trilok Kumar Sah        30000
# 1  SF00084|Trilok Kumar Sah  SF00084|Trilok Kumar Sah        30001
# 2  SF00084|Trilok Kumar Sah  SF00084|Trilok Kumar Sah        30002
# 3         SF00079|Prashant          SF00079|Prashant         30003
# 4         SF00079|Prashant          SF00079|Prashant         30004
#
#     customer_type  loan_id  ... product_group product_id  \
# ...

# %%
import pandas as pd

# Replace 'file_path.xlsx' with the path to your Excel file
df = pd.read_excel("F:\Daily Reports\center_size.xlsx")

# Group the DataFrame by the 'Area Name' column
grouped = df.groupby("Area name")

# Iterate over the groups and save each group as a separate Excel file
for area, data in grouped:
    # Create a new Excel file for each area
    file_name = f'{area}.xlsx'
    with pd.ExcelWriter(file_name) as writer:
        data.to_excel(writer, index=False)

# %%
import pandas as pd
import os  # Import os module for handling file paths

# Replace 'file_path.xlsx' with the path to your Excel file
df = pd.read_excel("F:\Daily Reports\center_size.xlsx")

# Group the DataFrame by the 'Area Name' column
grouped = df.groupby('Area name')

# Specify the directory where you want to save the Excel files
directory = "F:\Area"

# Create the 'Area' folder if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Iterate over the groups and save each group as a separate Excel file
for area, data in grouped:
    # Create the file path for each Excel file inside the 'Area' folder
    file_name = os.path.join(directory, f'{area}.xlsx')
    with pd.ExcelWriter(file_name) as writer:
        data.to_excel(writer, index=False)

# %%
import pandas as pd
import os  # Import os module for handling file paths

# Replace 'file_path.xlsx' with the path to your Excel file
df = pd.read_excel("F:\Daily Reports\center_size.xlsx")

# Filter the DataFrame based on your criteria
filtered_df = df[df["Active Center"] >= 2]  # Replace 'Your_Column' and 'Your_Value' with your criteria

# Group the filtered DataFrame by the 'Area Name' column
grouped = filtered_df.groupby('Area name')

# Specify the directory where you want to save the Excel files
directory = "F:\Area"

# Create the 'Area' folder if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Iterate over the groups and save each group as a separate Excel file
for area, data in grouped:
    # Create the file path for each Excel file inside the 'Area' folder
    file_name = os.path.join(directory, f'{area}.xlsx')
    with pd.ExcelWriter(file_name) as writer:
        data.to_excel(writer, index=False)

# %%
import pandas as pd
import os  # Import os module for handling file paths

# Replace 'file_path.xlsx' with the path to your Excel file
df = pd.read_excel("F:\Daily Reports\center_size.xlsx")

# Filter the DataFrame based on the 'Active Center' column
filtered_df = df[df['Active Center'] >= 2]

# Exclude rows with specific values in the 'app_status' column
filtered_df = filtered_df[~filtered_df['app_status'].isin(['REJECTED', 'DISBURSED', 'CB_VERIFICATION_FAILED','FOIR_REJECTED','CREDIT_SUBMIT_REJECTED','CLOSED','CBC_ERROR'])]

# Group the filtered DataFrame by the 'Area Name' column
grouped = filtered_df.groupby('Area name')

# Specify the directory where you want to save the Excel files
directory = "F:\Area"

# Create the 'Area' folder if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Iterate over the groups and save each group as a separate Excel file
for area, data in grouped:
    # Create the file path for each Excel file inside the 'Area' folder
    file_name = os.path.join(directory, f'{area}.xlsx')
    with pd.ExcelWriter(file_name) as writer:
        data.to_excel(writer, index=False)

# %%
import pandas as pd
import os  # Import os module for handling file paths
from datetime import datetime

# Replace 'file_path.xlsx' with the path to your Excel file
df = pd.read_excel("F:\Daily Reports\center_size.xlsx")

# Filter the DataFrame based on the 'Active Center' column
filtered_df = df[(df['Active Center'] >= 2) | ((df['Active Center'] < 2) & (df['Active center size'] >= 4))]

# Exclude rows with specific values in the 'app_status' column
filtered_df = filtered_df[~filtered_df['app_status'].isin(['REJECTED', 'DISBURSED', 'CB_VERIFICATION_FAILED','FOIR_REJECTED','CREDIT_SUBMIT_REJECTED','CLOSED','CBC_ERROR'])]

# Group the filtered DataFrame by the 'Area Name' column
grouped = filtered_df.groupby('Area name')

# Specify the directory where you want to save the Excel files
directory = "F:\Area"

# Create the 'Area' folder if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)


# Get today's date
today_date = datetime.today().strftime('%Y-%m-%d')

# Iterate over the groups and save each group as a separate Excel file
for area, data in grouped:
    # Create the file path for each Excel file inside the 'Area' folder
    file_count = len(data)
    file_name = os.path.join(directory, f'{area}_{file_count}_{today_date}.xlsx')
    with pd.ExcelWriter(file_name) as writer:
        data.to_excel(writer, index=False)

# %%
pip install xlsxwriter
# Out:
# ...
#    ---------------------------------------- 0.0/159.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/159.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/159.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/159.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/159.9 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/159.9 kB ? eta -:--:--
#    --------- ----------------------------- 41.0/159.9 kB 653.6 kB/s eta 0:00:01
#    -------------- ------------------------ 61.4/159.9 kB 656.4 kB/s eta 0:00:01
#    ---------------------- ---------------- 92.2/159.9 kB 581.0 kB/s eta 0:00:01
#    ----------------------------- -------- 122.9/159.9 kB 554.9 kB/s eta 0:00:01
#    ------------------------------------ - 153.6/159.9 kB 573.4 kB/s eta 0:00:01
#    -------------------------------------- 159.9/159.9 kB 562.7 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
from datetime import datetime

# Replace 'file_path.xlsx' with the path to your Excel file
df = pd.read_excel("F:\Daily Reports\center_size.xlsx")

# Filter the DataFrame based on the 'Active Center' column
filtered_df = df[(df['Active Center'] >= 2) | ((df['Active Center'] < 2) & (df['center size'] > 3))]

# Exclude rows with specific values in the 'app_status' column
filtered_df = filtered_df[~filtered_df['app_status'].isin(['REJECTED', 'DISBURSED', 'CB_VERIFICATION_FAILED'])]

# Group the filtered DataFrame by the 'Area Name' column
grouped = filtered_df.groupby('Area name')

# Specify the directory where you want to save the Excel files
directory = "F:\Area"

# Create the 'Area' folder if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Get today's date
today_date = datetime.today().strftime('%Y-%m-%d')

# Create a Pandas Excel writer using XlsxWriter as the engine
with pd.ExcelWriter(f'{directory}/Output_{today_date}.xlsx', engine='xlsxwriter') as writer:
    # Iterate over the groups and save each group as a separate Excel file
    for area, data in grouped:
        # Write each group to a separate worksheet
        data.to_excel(writer, sheet_name=area, index=False)

    # Create pivot table
    pivot_table_df = filtered_df.pivot_table(index='app_status', columns='Center Type', values='loan_id', aggfunc='count')
    pivot_table_df.to_excel(writer, sheet_name='Pivot_Table')

# %%
import pandas as pd
import os
from datetime import datetime

# Replace 'file_path.xlsx' with the path to your Excel file
df = pd.read_excel("F:\Daily Reports\center_size.xlsx")

# Filter the DataFrame based on the 'Active Center' column
filtered_df = df[(df['Active Center'] >= 2) | ((df['Active Center'] < 2) & (df['center size'] > 3))]

# Exclude rows with specific values in the 'app_status' column
filtered_df = filtered_df[~filtered_df['app_status'].isin(['REJECTED', 'DISBURSED', 'CB_VERIFICATION_FAILED'])]

# Group the filtered DataFrame by the 'Area Name' column
grouped = filtered_df.groupby('Area name')

# Specify the directory where you want to save the Excel files
directory = "F:\Area"

# Create the 'Area' folder if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Get today's date
today_date = datetime.today().strftime('%Y-%m-%d')

# Iterate over the groups and save each group as a separate Excel file
for area, data in grouped:
    # Create the file path for each Excel file inside the 'Area' folder
    file_count = len(data)
    file_name = os.path.join(directory, f'{area}_{file_count}records_{today_date}.xlsx')
    
    # Create a Pandas Excel writer for each area-wise file using XlsxWriter as the engine
    with pd.ExcelWriter(file_name, engine='xlsxwriter') as writer:
        # Write the data to the first sheet
        data.to_excel(writer, sheet_name='Data', index=False)
        
        # Create pivot table in another sheet
        pivot_table_df = data.pivot_table(index='app_status', columns='Center Type', values='Count of loan_id', aggfunc='count')
        pivot_table_df.to_excel(writer, sheet_name='Pivot_Table')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 39
#      36 data.to_excel(writer, sheet_name='Data', index=False)
#      38 # Create pivot table in another sheet
# ---> 39 pivot_table_df = data.pivot_table(index='app_status', columns='Center Type', values='Count of loan_id', aggfunc='count')
#      40 pivot_table_df.to_excel(writer, sheet_name='Pivot_Table')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9190, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9173 @Substitution("")
#    9174 @Appender(_shared_docs["pivot_table"])
#    9175 def pivot_table(
#    (...)
#    9186     sort: bool = True,
#    9187 ) -> DataFrame:
#    9188     from pandas.core.reshape.pivot import pivot_table
# -> 9190     return pivot_table(
#    9191         self,
# ...

# %%
import pandas as pd
import os
from datetime import datetime

# Replace 'file_path.xlsx' with the path to your Excel file
df = pd.read_excel("F:\Daily Reports\center_size.xlsx")

# Filter the DataFrame based on the 'Active Center' and 'Active center size' columns
filtered_df = df[(df['Active Center'] >= 2) | (df['Active center size'] >= 4)]

# Exclude rows with specific values in the 'app_status' column
filtered_df = filtered_df[~filtered_df['app_status'].isin(['REJECTED', 'DISBURSED', 'CB_VERIFICATION_FAILED','FOIR_REJECTED','CREDIT_SUBMIT_REJECTED','CLOSED','CBC_ERROR'])]

# Group the filtered DataFrame by the 'Area Name' column
grouped = filtered_df.groupby('Area name')

# Specify the directory where you want to save the Excel files
directory = "F:\Area"

# Create the 'Area' folder if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Get today's date
today_date = datetime.today().strftime('%Y-%m-%d')

# Iterate over the groups and save each group as a separate Excel file
for area, data in grouped:
    # Create the file path for each Excel file inside the 'Area' folder
    file_count = len(data)
    file_name = os.path.join(directory, f'{area}_{file_count}_{today_date}.xlsx')
    
    # Create a Pandas Excel writer for each area-wise file
    with pd.ExcelWriter(file_name) as writer:
        data.to_excel(writer, index=False)

# %%
import pandas as pd
import os
from datetime import datetime

# Replace 'file_path.xlsx' with the path to your Excel file
df = pd.read_excel("F:\Daily Reports\center_size.xlsx")

# Filter the DataFrame based on the 'Active Center' and 'Active center size' columns
filtered_df = df[(df['Active Center'] >= 2) | (df['Active center size'] >= 4)]

# Exclude rows with specific values in the 'app_status' column
filtered_df = filtered_df[~filtered_df['app_status'].isin(['REJECTED', 'DISBURSED', 'CB_VERIFICATION_FAILED','FOIR_REJECTED','CREDIT_SUBMIT_REJECTED','CLOSED','CBC_ERROR'])]

# Group the filtered DataFrame by the 'Area Name' column
grouped = filtered_df.groupby('Area name')

# Specify the directory where you want to save the Excel files
directory = "F:\Area"

# Create the 'Area' folder if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Get today's date
today_date = datetime.today().strftime('%Y-%m-%d')

# Iterate over the groups and save each group as a separate Excel file
for area, data in grouped:
    # Create the file path for each Excel file inside the 'Area' folder
    file_count = len(data)
    file_name = os.path.join(directory, f'{area}_{file_count}_{today_date}.xlsx')
    
    # Create a Pandas Excel writer for each area-wise file
    with pd.ExcelWriter(file_name) as writer:
        # Write data to the first sheet
        data.to_excel(writer, sheet_name='Data', index=False)
        
        # Create pivot table in another sheet
        pivot_table_df = data.pivot_table(index='app_status', columns='Center Type', values='Count of loan_id', aggfunc='count')
        pivot_table_df.to_excel(writer, sheet_name='Pivot_Table')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 39
#      36 data.to_excel(writer, sheet_name='Data', index=False)
#      38 # Create pivot table in another sheet
# ---> 39 pivot_table_df = data.pivot_table(index='app_status', columns='Center Type', values='Count of loan_id', aggfunc='count')
#      40 pivot_table_df.to_excel(writer, sheet_name='Pivot_Table')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9190, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9173 @Substitution("")
#    9174 @Appender(_shared_docs["pivot_table"])
#    9175 def pivot_table(
#    (...)
#    9186     sort: bool = True,
#    9187 ) -> DataFrame:
#    9188     from pandas.core.reshape.pivot import pivot_table
# -> 9190     return pivot_table(
#    9191         self,
# ...
